# %%
import pandas as pd
import pandas_datareader as pdr
import matplotlib.pyplot as plt
import yfinance as yfin

# %%
start_date = "2020-01-1"
end_date = "2020-12-31"

# %%
yfin.pdr_override()

# %%
data = pdr.get_data_yahoo("TSLA")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-5e357660f4c1> in <cell line: 1>()
# ----> 1 data = pdr.get_data_yahoo("TSLA")
#
# /usr/local/lib/python3.10/dist-packages/pandas_datareader/data.py in get_data_yahoo(*args, **kwargs)
#      78
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#      81
#      82
#
# /usr/local/lib/python3.10/dist-packages/pandas_datareader/base.py in read(self)
#     251         # If a single symbol, (e.g., 'GOOG')
#     252         if isinstance(self.symbols, (string_types, int)):
# --> 253             df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254         # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255         elif isinstance(self.symbols, DataFrame):
#
# ...

# %%
import pandas
from pandas_datareader import data as pdr
import yfinance as yfin


yfin.pdr_override()

df = pdr.get_data_yahoo('TSLA', start='2017-12-31', end='2022-12-23')

df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02   20.799999   21.474001   20.733334   21.368668   21.368668
# 2018-01-03   21.400000   21.683332   21.036667   21.150000   21.150000
# 2018-01-04   20.858000   21.236668   20.378668   20.974667   20.974667
# 2018-01-05   21.108000   21.149332   20.799999   21.105333   21.105333
# 2018-01-08   21.066668   22.468000   21.033333   22.427334   22.427334
# ...                ...         ...         ...         ...         ...
# 2022-12-16  159.639999  160.990005  150.039993  150.229996  150.229996
# 2022-12-19  154.000000  155.250000  145.820007  149.869995  149.869995
# 2022-12-20  146.050003  148.470001  137.660004  137.800003  137.800003
# 2022-12-21  139.339996  141.259995  135.889999  137.570007  137.570007
# 2022-12-22  136.000000  136.630005  122.260002  125.349998  125.349998
#
#                Volume
# Date
# ...

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-12-16  159.639999  160.990005  150.039993  150.229996  150.229996
# 2022-12-19  154.000000  155.250000  145.820007  149.869995  149.869995
# 2022-12-20  146.050003  148.470001  137.660004  137.800003  137.800003
# 2022-12-21  139.339996  141.259995  135.889999  137.570007  137.570007
# 2022-12-22  136.000000  136.630005  122.260002  125.349998  125.349998
#
#                Volume
# Date
# 2022-12-16  139032200
# 2022-12-19  139390600
# 2022-12-20  159563300
# 2022-12-21  145417400
# 2022-12-22  210090300

# %%
close = df['Close']
ax = close.plot(title='Tesla')
ax.set_xlabel('Date')
ax.set_ylabel('Close')
ax.grid()
plt.show()

# %%
df["High"].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df["High"].plot(xlim=['2020-01-01','2021-01-01'],ylim=[0,300],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
index=df.loc['2020-01-01':'2021-09-01'].index
share_open=df.loc['2020-01-01':'2021-09-01']['Open']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis=plt.subplots()
plt.tight_layout()
## Preventing overlapping
figure.autofmt_xdate()
axis.plot(index,share_open)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1254 entries, 2018-01-02 to 2022-12-22
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1254 non-null   float64
#  1   High       1254 non-null   float64
#  2   Low        1254 non-null   float64
#  3   Close      1254 non-null   float64
#  4   Adj Close  1254 non-null   float64
#  5   Volume     1254 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 100.9 KB

# %%
df_tesla=df.reset_index()
df_tesla
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-01-02   20.799999   21.474001   20.733334   21.368668   21.368668
# 1    2018-01-03   21.400000   21.683332   21.036667   21.150000   21.150000
# 2    2018-01-04   20.858000   21.236668   20.378668   20.974667   20.974667
# 3    2018-01-05   21.108000   21.149332   20.799999   21.105333   21.105333
# 4    2018-01-08   21.066668   22.468000   21.033333   22.427334   22.427334
# ...         ...         ...         ...         ...         ...         ...
# 1249 2022-12-16  159.639999  160.990005  150.039993  150.229996  150.229996
# 1250 2022-12-19  154.000000  155.250000  145.820007  149.869995  149.869995
# 1251 2022-12-20  146.050003  148.470001  137.660004  137.800003  137.800003
# 1252 2022-12-21  139.339996  141.259995  135.889999  137.570007  137.570007
# 1253 2022-12-22  136.000000  136.630005  122.260002  125.349998  125.349998
#
#          Volume
# 0      65283000
# 1      67822500
# ...

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1254 entries, 0 to 1253
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1254 non-null   datetime64[ns]
#  1   Open       1254 non-null   float64
#  2   High       1254 non-null   float64
#  3   Low        1254 non-null   float64
#  4   Close      1254 non-null   float64
#  5   Adj Close  1254 non-null   float64
#  6   Volume     1254 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 68.7 KB

# %%
# df_tesla=df_tesla.set_index('Date',drop=True)

# %%
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02   20.799999   21.474001   20.733334   21.368668   21.368668
# 2018-01-03   21.400000   21.683332   21.036667   21.150000   21.150000
# 2018-01-04   20.858000   21.236668   20.378668   20.974667   20.974667
# 2018-01-05   21.108000   21.149332   20.799999   21.105333   21.105333
# 2018-01-08   21.066668   22.468000   21.033333   22.427334   22.427334
# ...                ...         ...         ...         ...         ...
# 2022-12-16  159.639999  160.990005  150.039993  150.229996  150.229996
# 2022-12-19  154.000000  155.250000  145.820007  149.869995  149.869995
# 2022-12-20  146.050003  148.470001  137.660004  137.800003  137.800003
# 2022-12-21  139.339996  141.259995  135.889999  137.570007  137.570007
# 2022-12-22  136.000000  136.630005  122.260002  125.349998  125.349998
#
#                Volume
# Date
# 2018-01-02   65283000
# 2018-01-03   67822500
# 2018-01-04  149194500
# ...

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 10, 3, 12, 15, 47, 68517)

# %%
df.resample(rule='A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# 2022-12-31  136.000000  136.630005  122.260002  125.349998  125.349998
#
#               Volume
# Date
# 2018-12-31  46210500
# 2019-12-31  36984000
# 2020-12-31  52073100
# 2021-12-31  29401800
# 2022-12-31  41864700

# %%
closedf = df_tesla[['Date','Close']]
print("Shape of close dataframe:", closedf.shape)
# Out:
# Shape of close dataframe: (1254, 2)

# %%
closedf
# Out:
#            Date       Close
# 0    2018-01-02   21.368668
# 1    2018-01-03   21.150000
# 2    2018-01-04   20.974667
# 3    2018-01-05   21.105333
# 4    2018-01-08   22.427334
# ...         ...         ...
# 1249 2022-12-16  150.229996
# 1250 2022-12-19  149.869995
# 1251 2022-12-20  137.800003
# 1252 2022-12-21  137.570007
# 1253 2022-12-22  125.349998
#
# [1254 rows x 2 columns]

# %%
#create a new dataframe only with close column
close_df = closedf.filter(['Close'])
close_df.shape
# Out:
# (1254, 1)

# %%
close_df
# Out:
#            Close
# 0      21.368668
# 1      21.150000
# 2      20.974667
# 3      21.105333
# 4      22.427334
# ...          ...
# 1249  150.229996
# 1250  149.869995
# 1251  137.800003
# 1252  137.570007
# 1253  125.349998
#
# [1254 rows x 1 columns]

# %%
#ploting close
plt.plot(close_df)

# %%
#convert the dataframe into numpy array
# dataset_close = close_df.values
# len(dataset_close)
# Out:
# 1254

# %%
close_df
# Out:
#            Close
# 0      21.368668
# 1      21.150000
# 2      20.974667
# 3      21.105333
# 4      22.427334
# ...          ...
# 1249  150.229996
# 1250  149.869995
# 1251  137.800003
# 1252  137.570007
# 1253  125.349998
#
# [1254 rows x 1 columns]

# %% [markdown]
# Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
dataset_close1 = scaler.fit_transform(np.array(close_df).reshape(-1,1))

# %%
dataset_close1.shape
# Out:
# (1254, 1)

# %%
#spliting the dataset into train and test split
training_size = int(len(dataset_close1) * 0.70)
test_size = len(dataset_close1)-training_size

# %%
training_size,test_size
# Out:
# (877, 377)

# %%
train_data,test_data  = dataset_close1[0:training_size,:],dataset_close1[training_size:len(dataset_close1),:1]

# %%
len(train_data),len(test_data)
# Out:
# (877, 377)

# %%
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX), np.array(dataY)

# %% [markdown]
# Taking timestep of 100. That is the new value will be predicted based on previous 100 days data.*italicized text*

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
X_train.shape,y_train.shape
# Out:
# ((776, 100), (776,))

# %%
X_test.shape,y_test.shape
# Out:
# ((276, 100), (276,))

# %% [markdown]
# Reshaping input into three dimentions for LSTM
#
# ---
#
#
#
# ```

# %%
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
X_train.shape
# Out:
# (776, 100, 1)

# %% [markdown]
# Creating Stacked LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
##stacked LSTM model
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# ...
# Total params: 50851 (198.64 KB)
# Trainable params: 50851 (198.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 11s 380ms/step - loss: 0.0230 - val_loss: 0.0361
# Epoch 2/100
# 13/13 [==============================] - 3s 192ms/step - loss: 0.0038 - val_loss: 0.0067
# Epoch 3/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.0016 - val_loss: 0.0064
# Epoch 4/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.0014 - val_loss: 0.0055
# Epoch 5/100
# 13/13 [==============================] - 2s 183ms/step - loss: 0.0010 - val_loss: 0.0057
# Epoch 6/100
# 13/13 [==============================] - 4s 279ms/step - loss: 9.4857e-04 - val_loss: 0.0065
# Epoch 7/100
# 13/13 [==============================] - 2s 182ms/step - loss: 0.0010 - val_loss: 0.0064
# Epoch 8/100
# 13/13 [==============================] - 2s 193ms/step - loss: 9.7789e-04 - val_loss: 0.0053
# Epoch 9/100
# 13/13 [==============================] - 3s 198ms/step - loss: 9.7382e-04 - val_loss: 0.0062
# Epoch 10/100
# ...

# %%
#prediction
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# ...
# 9/9 [==============================] - 0s 37ms/step

# %%
#transforming the output to the original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
# Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 110.29129563730352

# %%
# Test Data RMSE
math.sqrt(mean_squared_error(y_test,test_predict))
# Out:
# 258.954726560388

# %% [markdown]
# ploting model performance

# %%
from sklearn.metrics.pairwise import np

look_back = 100

trainPredictPlot = np.empty_like(dataset_close1)
trainPredictPlot[:] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back] = train_predict

testPredictPlot = np.empty_like(dataset_close1)
testPredictPlot[:] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(dataset_close1)-1] = test_predict

plt.plot(scaler.inverse_transform(dataset_close1), label='Actual Data')
plt.plot(trainPredictPlot, label='Training Predictions')
plt.plot(testPredictPlot, label='Test Predictions')

plt.legend()
plt.show()

# %%
len(test_data)
# Out:
# 377

# %%
X_input = test_data[277:].reshape(1,-1) #previous 100 days data before from 377
X_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(X_input)
temp_input=temp_input[0].tolist()

# %%
temp_input
# Out:
# [0.7423030930823052,
#  0.7454099867482097,
#  0.6939996101096859,
#  0.6996606842554646,
#  0.6818483537041419,
#  0.7095424354564474,
#  0.690130617807474,
#  0.7237956733723544,
#  0.7471351357839799,
#  0.7402094685891816,
#  0.7337612247553779,
#  0.730930649347547,
#  0.7153458855748238,
#  0.6983793771719664,
#  0.7148099630931549,
#  0.7164262408951668,
#  0.7138469126936922,
#  0.6937985816766479,
#  0.6855833270509951,
#  0.6676956300047538,
#  0.6624448164025247,
#  0.6663389564263372,
#  0.6488783106280067,
#  0.6594552276575006,
#  0.6827695423475256,
#  0.6967380283182368,
#  0.7229163464850494,
#  0.7348247893713595,
#  0.7039483707883482,
#  0.7302774219449978,
#  0.7331415020916682,
#  0.7321365899361266,
#  0.746507056103031,
#  0.7456528769373266,
#  0.7257301311885189,
#  0.6950547410385455,
#  0.6617413702266574,
#  0.6634498052279492,
#  0.6808601555830787,
#  0.6930951355007805,
#  0.6438536731804161,
#  0.6364172312255493,
#  0.5790107330528501,
# ...

# %%
len(temp_input)

# %% [markdown]
# Predicting output for next 30 days

# %%
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<30):

    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
print(lst_output)
# Out:
# 0 day input [0.68184835 0.70954244 0.69013062 0.72379567 0.74713514 0.74020947
#  0.73376122 0.73093065 0.71534589 0.69837938 0.71480996 0.71642624
#  0.71384691 0.69379858 0.68558333 0.66769563 0.66244482 0.66633896
#  0.64887831 0.65945523 0.68276954 0.69673803 0.72291635 0.73482479
#  0.70394837 0.73027742 0.7331415  0.73213659 0.74650706 0.74565288
#  0.72573013 0.69505474 0.66174137 0.66344981 0.68086016 0.69309514
#  0.64385367 0.63641723 0.57901073 0.59669748 0.57501616 0.56828316
#  0.53044765 0.53017129 0.51394169 0.51580082 0.527056   0.48502492
#  0.52110182 0.52321216 0.52785992 0.49077811 0.50876632 0.50075202
#  0.52881462 0.53439197 0.5355225  0.54413978 0.54167768 0.54238116
#  0.51012296 0.51095203 0.49125546 0.46515247 0.45063127 0.41618736
#  0.44917412 0.46236379 0.44975194 0.45846969 0.4396273  0.43020611
#  0.42271941 0.39176762 0.39689277 0.43028147 0.42942729 0.42957803
#  0.42432729 0.45917314 0.45917314 0.45957512 0.42839723 0.42178986
# ...

# %%
day_new=np.arange(0,100)
day_pred=np.arange(100,130)

# %%
len(lst_output)
# Out:
# 30

# %%
scaler.inverse_transform(lst_output)
# Out:
# array([[142.54828089],
#        [144.3323618 ],
#        [146.02851803],
#        [147.57552735],
#        [148.97594018],
#        [150.24504725],
#        [151.39421282],
#        [152.42979517],
#        [153.35600549],
#        [154.17798023],
#        [154.90344186],
#        [155.54263955],
#        [156.1080052 ],
#        [156.61301455],
#        [157.07127389],
#        [157.49583193],
#        [157.89856302],
#        [158.28975191],
#        [158.67795147],
#        [159.06992328],
#        [159.47054285],
#        [159.88320283],
#        [160.3097419 ],
#        [160.75077692],
#        [161.20594016],
#        [161.67405721],
#        [162.15328941],
#        [162.6415964 ],
#        [163.136665  ],
#        [163.636099  ]])

# %%
len(dataset_close1)
# Out:
# 1254

# %% [markdown]
# Ploting the predicting output for next 30 days

# %%
plt.plot(day_new,scaler.inverse_transform(dataset_close1[1154:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))

# %%
df3 =  dataset_close1.tolist()
df3.extend(lst_output)
plt.plot(df3[1200:])

# %%
import numpy as np
import matplotlib.pyplot as plt

df3 = dataset_close1.tolist()
lst_output_list = lst_output.tolist()  # Convert lst_output to a list

# Extend df3 with lst_output_list
df3 = np.concatenate([df3, lst_output_list])

plt.plot(df3[1200:], label='Actual Data and Final Prediction for Next 30 Days')

# Add a label indicating "final prediction for next 30 days" in the right top corner
x_coord = len(df3[1200:]) - 10
y_coord = max(df3[1200:]) + 10
plt.text(x_coord, y_coord, 'Final Prediction for Next 30 Days', fontsize=12, color='red', horizontalalignment='right', verticalalignment='top')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-146-a3d804ad57a7> in <cell line: 5>()
#       3
#       4 df3 = dataset_close1.tolist()
# ----> 5 lst_output_list = lst_output.tolist()  # Convert lst_output to a list
#       6
#       7 # Extend df3 with lst_output_list
#
# AttributeError: 'list' object has no attribute 'tolist'
